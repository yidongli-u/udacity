# %% [markdown]
# # Model1 - Amissions: Accept or Reject?

# %% [markdown]
# ## Based on findings from feature selections work files:
#  * successful-student-profile/feature-selection-1.ipynb
#  * successful-student-profile/feature-selection-2-with-clustering.ipynb
#  * successful-student-profile/feature-selection-3-with-ND-separated.ipynb
#  * successful-student-profile/apps-goal-text-analysis-NB.ipynb
#
# ## Let's build our first model!

# %% [markdown]
# Output: % of graduation of each students
#  * assumptions: our data visibility stops after student submit the application
#        means we know when the cohort is open, close, start; when student apply, submit; but we don't know when we are going to accept/reject and notify the student, when the student going to put down payment
#
# Approach: ND separated; application type separated
#
# Methods: Logistics Regression / Decision Tree
#
# Features:
#  * user_age : account created with Udacity
#  * cohort_open_to_notify
#  * cohort_open_to_close
#  * apply_before_start : days student apply before cohort start
#  * apply_to_submit : days from apply to submit application
#  * num_course_enrolled
#
#  * education
#  * employment
#  * professional experience
#  * python, java, c++, porbability, statistics, linear algebra, computer science, machine learning
#
#  * mentioned programming skills / technology in goal

# %%
import psycopg2
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import linear_model
from sklearn.metrics import accuracy_score
import statsmodels.api as sm
import random
import re
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
laurel = open('conn_laurel.txt', 'r')
hardy = open('conn_hardy.txt', 'r')
conn_laurel = psycopg2.connect(laurel.read())
conn_hardy = psycopg2.connect(hardy.read())

sql_apps = open('successful-student-profile-apps.sql', 'r')
sql_courses = open('successful-student-profile-courses.sql', 'r')
sql_questions = open('successful-student-profile-questions.sql', 'r')

df_apps = pd.read_sql(sql_apps.read(),conn_laurel)
df_courses = pd.read_sql(sql_courses.read(),conn_hardy)
df_questions = pd.read_sql(sql_questions.read(),conn_laurel)

# %%
df_apps.groupby(['nd_key','application_status'])['application_id'].count()
# Out:
# nd_key              application_status
# nd001-connect       paid                     1
# nd002-connect       paid                    20
# nd004-connect-reno  graduated                4
#                     paid                    16
# nd009-connect       paid                    27
# nd013               graduated                4
#                     paid                  2663
#                     term completed         780
# nd209               graduated                4
#                     paid                  1160
#                     term completed         117
# nd889               paid                  1175
#                     term completed          29
# Name: application_id, dtype: int64

# %%
df = pd.merge(df_apps,df_courses,on=['application_id','cohort_id','applicant_id','nd_key'],how='left')

# %% [markdown]
# ## Based on the pivot above, let's pick nd013 as pilot to model.

# %%
df_nd013 = df.query("nd_key == 'nd013'")
df_nd013 = df_nd013.assign(status = df_nd013['application_status'].map({'graduated':1,'term completed':1,'paid':0}))
print(df_nd013.shape)
df_nd013.columns
# Out:
# (3447, 24)
# Index(['application_id', 'cohort_id', 'applicant_id', 'nd_key',
#        'application_type', 'applicant_country', 'applicant_geo',
#        'application_status', 'user_age', 'cohort_open_to_notify',
#        'cohort_open_to_close', 'cohort_open_month', 'application_month',
#        'apply_before_start', 'apply_to_submit', 'submit_to_decision',
#        'submit_to_notify', 'notify_to_pay', 'price', 'num_courses',
#        'num_course_finished', 'num_course_enrolled', 'user_study_age',
#        'status'],
#       dtype='object')

# %%
df_nd013.groupby(['cohort_id','application_status'])['application_id'].count()
# Out:
# cohort_id  application_status
# 18         graduated               4
#            paid                  619
#            term completed        492
# 220        paid                  322
# 47         paid                  544
#            term completed        266
# 88         paid                  781
#            term completed         19
# 89         paid                  397
#            term completed          3
# Name: application_id, dtype: int64

# %%
# among cohorts 18,47,88,89,220, cohort 18 and 47 are closed. cohort 88 is closing in Dec
df_nd013 = df_nd013.loc[(df_nd013['cohort_id']=='18') | (df_nd013['cohort_id']=='47')]
df_nd013.shape
# Out:
# (1925, 24)

# %%
# only columns we care about
cols = ['status','application_id','user_age','cohort_open_to_notify','cohort_open_to_close'
        ,'apply_before_start','apply_to_submit','num_course_enrolled']
df_nd013 = df_nd013[cols]

# %%
# from questions_responses
# categorical
df1 = df_nd013
categories = {'education':'48e7b492-62b4-4d99-b596-80d68f2966ae'
             ,'employment':'fba3666b-db04-46e9-8f3d-2a303f13e0a5'
             ,'professional_experience':'6967091c-09c6-4455-9f1e-d0de318bacc5'
             ,'goal':'779c3b6c-3648-423b-8d3f-8a4f36f23e2a'}
for i,qr_id in categories.items():
    d = df_questions.copy()
    d[i] = 0
    d[i] = np.where(d['question_id']==qr_id,d['response'],'0')
    o_i = d.groupby('application_id').agg({i:'max'}).reset_index()
    o_i = o_i[o_i.iloc[:,1] != '0']
    o_i = o_i[o_i.iloc[:,1] != 'Other']
    #df1 = pd.merge(df1,o_i,on=['application_id'],how='inner')
    d_i = pd.get_dummies(o_i[i])
    df_i = pd.concat([o_i['application_id'],d_i],axis=1)
    df1 = pd.merge(df1,df_i,on='application_id',how='left')

# %%
# from questions_responses
# programming languages
data = df1
for i in (['python','java','cplus','probability','statistics','linear algebra','computer science','machine learning']):
    if i == 'cplus':
        j = 'c\+\+' 
    else:
        j = i
    d = df_questions.copy()
    d[i] = 0
    d[i] = np.where(d['response'].str.lower().str.contains(j),1,d[i])
    d[i] = np.where(d['question_prompt'].str.lower().str.contains(j)&d['response'].str.match('.*[1-9].*'),1,d[i])
    o_i = d.groupby('application_id').agg({i:'max'}).reset_index()
    data = pd.merge(data,o_i,on=['application_id'],how='left')

# %%
print(data.columns)
# Out:
# Index(['status', 'application_id', 'user_age', 'cohort_open_to_notify',
#        'cohort_open_to_close', 'apply_before_start', 'apply_to_submit',
#        'num_course_enrolled', 'Bachelor's degree', 'High school degree',
#        'Master's degree', 'PhD', 'Self employed', 'Student', 'Unemployed',
#        'Yes, full time', 'Yes, part time or contract', '1-2+ years',
#        '3-5 years', '5+ years', '< 1 year',
#        'I have no professional experience',
#        'General interest in the topic (personal growth and enrichment)',
#        'Grow skills for my current role',
#        'Help move from academia to industry',
#        'Help prepare for an advanced degree',
#        'Start a new career in this field', 'python', 'java', 'cplus',
#        'probability', 'statistics', 'linear algebra', 'computer science',
#        'machine learning'],
#       dtype='object')

# %%
# from goals : text
#data
df_goal = df_questions.loc[df_questions['question_id'].isin(['2ad03aaa-1b35-4381-9c43-907b1b4eba67','6afe0061-746b-4bd7-807c-393fe5c7599d'])]

# %%
d = df_goal.copy()
d['goal'] = 0
# mentioned ND
education_words = ['self','driving','car','cars'] #['ai','artificial','intelligence']
# technology related?
technology_words = ['computer','science','machine','learning','deep','learning','learn']
d['goal'] = np.where(d['response'].str.lower().str.contains(j),1,d[i])
d['goal'] = np.where(d['question_prompt'].str.lower().str.contains(j)&d['response'].str.match('.*[1-9].*'),1,d[i])
o = d.groupby('application_id').agg({i:'max'}).reset_index()
data = pd.merge(data,o,on=['application_id'],how='left')
# Out:
#                           application_id cohort_id applicant_id   nd_key  \
# 0   0001883b-f88d-4662-afea-717fbba580a0       129   4746120864    nd889
# 10  0002c98e-89a9-4d54-a48d-ce3586bc10b2        18  10469833750    nd013
# 19  00036e7d-377a-4a85-90cb-a51d870b167c     ntc-2  10567564644  nd001sa
# 33  0006fc3d-bd9f-465a-8600-7a87a659c5ee       283  11052205644    nd889
# 64  000c3078-246a-4175-93da-8d51db496263        88  10411698310    nd013
#
#                              question_id  \
# 0   2ad03aaa-1b35-4381-9c43-907b1b4eba67
# 10  2ad03aaa-1b35-4381-9c43-907b1b4eba67
# 19  2ad03aaa-1b35-4381-9c43-907b1b4eba67
# 33  2ad03aaa-1b35-4381-9c43-907b1b4eba67
# 64  2ad03aaa-1b35-4381-9c43-907b1b4eba67
#
#                                       question_prompt  \
# 0   What do you hope to accomplish through this pr...
# 10  What do you hope to accomplish through this pr...
# 19  What do you hope to accomplish through this pr...
# 33  What do you hope to accomplish through this pr...
# 64  What do you hope to accomplish through this pr...
#
#                                              response  \
# 0   I am currently writing Machine Learning Code a...
# 10  I'm currently studying master of mechanical/au...
# 19  The technical field is the most important area...
# 33  I completed a biomedical engineer bachelors de...
# 64  I hope to get engaged in such rich field, as I...
#
#                                                   q_r
# 0   What do you hope to accomplish through this pr...
# 10  What do you hope to accomplish through this pr...
# 19  What do you hope to accomplish through this pr...
# 33  What do you hope to accomplish through this pr...
# 64  What do you hope to accomplish through this pr...

# %%
# split into training and test data set
#data = data.fillna(0)
ratio = 0.1
N = data.shape[0]
index = random.sample(range(N),int(ratio*N))
TEST = data[data.index.isin(index)]
TRAIN = data[~data.index.isin(index)]
X_train = TRAIN.iloc[:,2:]
y_train = TRAIN.iloc[:,0]
X_test = TEST.iloc[:,2:]
y_test = TEST.iloc[:,0]

# %%
clf = linear_model.LogisticRegression()
clf.fit(X_train,y_train)
predictions = clf.predict(X_test)
accuracy_score(y_test, predictions)
# Out:
# 0.63376623376623376

# %%
features = X_train.describe().T
features
# Out:
#                                                      count        mean  \
# user_age                                            1540.0  208.459740
# cohort_open_to_notify                               1540.0   78.575974
# cohort_open_to_close                                1540.0   64.263636
# apply_before_start                                  1540.0   39.233117
# apply_to_submit                                     1540.0    5.090260
# num_course_enrolled                                 1540.0    0.269481
# Bachelor's degree                                   1540.0    0.317532
# High school degree                                  1540.0    0.034416
# Master's degree                                     1540.0    0.490260
# PhD                                                 1540.0    0.136364
# Self employed                                       1540.0    0.059740
# Student                                             1540.0    0.134416
# Unemployed                                          1540.0    0.048052
# Yes, full time                                      1540.0    0.687013
# Yes, part time or contract                          1540.0    0.061039
# 1-2+ years                                          1540.0    0.206494
# 3-5 years                                           1540.0    0.164935
# 5+ years                                            1540.0    0.477273
# < 1 year                                            1540.0    0.100000
# I have no professional experience                   1540.0    0.051299
# General interest in the topic (personal growth ...  1540.0    0.119481
# Grow skills for my current role                     1540.0    0.298052
# Help move from academia to industry                 1540.0    0.078571
# Help prepare for an advanced degree                 1540.0    0.025974
# Start a new career in this field                    1540.0    0.472078
# python                                              1540.0    0.966883
# java                                                1540.0    0.025325
# cplus                                               1540.0    0.925974
# probability                                         1540.0    0.942208
# statistics                                          1540.0    0.942857
# linear algebra                                      1540.0    0.935714
# computer science                                    1540.0    0.924026
# machine learning                                    1540.0    0.763636
#
#                                                           std    min    25%  \
# user_age                                            35.923955  147.0  178.0
# cohort_open_to_notify                               11.314745   65.0   65.0
# cohort_open_to_close                                 6.887236   56.0   56.0
# apply_before_start                                  20.229054   -1.0   22.0
# apply_to_submit                                     11.561640    0.0    0.0
# num_course_enrolled                                  2.581381    0.0    0.0
# Bachelor's degree                                    0.465668    0.0    0.0
# High school degree                                   0.182353    0.0    0.0
# Master's degree                                      0.500068    0.0    0.0
# PhD                                                  0.343286    0.0    0.0
# Self employed                                        0.237082    0.0    0.0
# Student                                              0.341209    0.0    0.0
# Unemployed                                           0.213946    0.0    0.0
# Yes, full time                                       0.463860    0.0    0.0
# Yes, part time or contract                           0.239480    0.0    0.0
# 1-2+ years                                           0.404920    0.0    0.0
# 3-5 years                                            0.371242    0.0    0.0
# 5+ years                                             0.499645    0.0    0.0
# < 1 year                                             0.300097    0.0    0.0
# I have no professional experience                    0.220678    0.0    0.0
# General interest in the topic (personal growth ...   0.324458    0.0    0.0
# Grow skills for my current role                      0.457551    0.0    0.0
# Help move from academia to industry                  0.269156    0.0    0.0
# Help prepare for an advanced degree                  0.159109    0.0    0.0
# Start a new career in this field                     0.499382    0.0    0.0
# python                                               0.179000    0.0    1.0
# java                                                 0.157160    0.0    0.0
# cplus                                                0.261898    0.0    1.0
# probability                                          0.233426    0.0    1.0
# statistics                                           0.232191    0.0    1.0
# linear algebra                                       0.245341    0.0    1.0
# computer science                                     0.265043    0.0    1.0
# machine learning                                     0.424986    0.0    1.0
#
#                                                       50%    75%    max
# user_age                                            209.0  237.0  271.0
# cohort_open_to_notify                                88.0   88.0   88.0
# cohort_open_to_close                                 70.0   70.0   70.0
# apply_before_start                                   42.0   55.0   70.0
# apply_to_submit                                       0.0    2.0   67.0
# num_course_enrolled                                   0.0    0.0   92.0
# Bachelor's degree                                     0.0    1.0    1.0
# High school degree                                    0.0    0.0    1.0
# Master's degree                                       0.0    1.0    1.0
# PhD                                                   0.0    0.0    1.0
# Self employed                                         0.0    0.0    1.0
# Student                                               0.0    0.0    1.0
# Unemployed                                            0.0    0.0    1.0
# Yes, full time                                        1.0    1.0    1.0
# Yes, part time or contract                            0.0    0.0    1.0
# 1-2+ years                                            0.0    0.0    1.0
# 3-5 years                                             0.0    0.0    1.0
# 5+ years                                              0.0    1.0    1.0
# < 1 year                                              0.0    0.0    1.0
# I have no professional experience                     0.0    0.0    1.0
# General interest in the topic (personal growth ...    0.0    0.0    1.0
# Grow skills for my current role                       0.0    1.0    1.0
# Help move from academia to industry                   0.0    0.0    1.0
# Help prepare for an advanced degree                   0.0    0.0    1.0
# Start a new career in this field                      0.0    1.0    1.0
# python                                                1.0    1.0    1.0
# java                                                  0.0    0.0    1.0
# cplus                                                 1.0    1.0    1.0
# probability                                           1.0    1.0    1.0
# statistics                                            1.0    1.0    1.0
# linear algebra                                        1.0    1.0    1.0
# computer science                                      1.0    1.0    1.0
# machine learning                                      1.0    1.0    1.0

# %%
logit = sm.Logit(y_train,X_train)
result = logit.fit()
print(result.summary())
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.639623
#          Iterations: 35
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 status   No. Observations:                 1540
# Model:                          Logit   Df Residuals:                     1508
# Method:                           MLE   Df Model:                           31
# Date:                Tue, 14 Nov 2017   Pseudo R-squ.:                 0.04413
# Time:                        15:37:26   Log-Likelihood:                -985.02
# converged:                      False   LL-Null:                       -1030.5
#                                         LLR p-value:                 8.389e-08
# ==================================================================================================================================
#                                                                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------
# user_age                                                           0.0022      0.004      0.550      0.582      -0.006       0.010
# cohort_open_to_notify                                              0.1242        nan        nan        nan         nan         nan
# cohort_open_to_close                                              -0.1733        nan        nan        nan         nan         nan
# apply_before_start                                                 0.0020      0.005      0.427      0.669      -0.007       0.011
# apply_to_submit                                                    0.0023      0.005      0.461      0.645      -0.007       0.012
# num_course_enrolled                                               -0.0082      0.027     -0.305      0.761      -0.061       0.044
# Bachelor's degree                                                 -0.0872      0.394     -0.221      0.825      -0.860       0.685
# High school degree                                                -0.2099      0.501     -0.419      0.676      -1.193       0.773
# Master's degree                                                    0.2882      0.391      0.738      0.461      -0.478       1.054
# PhD                                                                0.5014      0.411      1.221      0.222      -0.303       1.306
# Self employed                                                     -0.8541      0.600     -1.423      0.155      -2.030       0.322
# Student                                                           -1.2007      0.583     -2.059      0.039      -2.344      -0.058
# Unemployed                                                        -1.2452      0.614     -2.027      0.043      -2.449      -0.041
# Yes, full time                                                    -1.2682      0.565     -2.245      0.025      -2.375      -0.161
# Yes, part time or contract                                        -1.2032      0.601     -2.001      0.045      -2.382      -0.025
# 1-2+ years                                                        -0.0045        nan        nan        nan         nan         nan
# 3-5 years                                                          0.1246        nan        nan        nan         nan         nan
# 5+ years                                                           0.1825        nan        nan        nan         nan         nan
# < 1 year                                                          -0.0385        nan        nan        nan         nan         nan
# I have no professional experience                                 -0.2792        nan        nan        nan         nan         nan
# General interest in the topic (personal growth and enrichment)     0.1000      0.748      0.134      0.894      -1.366       1.566
# Grow skills for my current role                                    0.4291      0.738      0.581      0.561      -1.018       1.876
# Help move from academia to industry                                0.3335      0.757      0.441      0.659      -1.149       1.816
# Help prepare for an advanced degree                               -0.3149      0.826     -0.381      0.703      -1.933       1.304
# Start a new career in this field                                   0.3276      0.734      0.446      0.656      -1.112       1.767
# python                                                             0.8620      0.372      2.320      0.020       0.134       1.590
# java                                                              -0.0551      0.356     -0.155      0.877      -0.753       0.643
# cplus                                                              0.0730      0.214      0.342      0.733      -0.346       0.492
# probability                                                       15.3260   3307.389      0.005      0.996   -6467.038    6497.690
# statistics                                                       -15.1385   3307.389     -0.005      0.996   -6497.503    6467.226
# linear algebra                                                    -0.0970      0.243     -0.399      0.690      -0.573       0.379
# computer science                                                  -0.3046      0.206     -1.481      0.139      -0.708       0.099
# machine learning                                                   0.3993      0.135      2.962      0.003       0.135       0.663
# ==================================================================================================================================
# /anaconda/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /anaconda/lib/python3.6/site-packages/statsmodels/base/model.py:1029: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(np.diag(self.cov_params()))
# /anaconda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /anaconda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /anaconda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
from keras.models import Sequential
from keras.layers import Conv2D

model = Sequential()
model.add(Conv2D(filters=32, kernel_size=3, strides=2, padding='same', 
    activation='relu', input_shape=(128, 128, 3)))
model.summary()
# Out:
# Using TensorFlow backend.
# /anaconda/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        896
# =================================================================
# Total params: 896
# Trainable params: 896
# Non-trainable params: 0
# _________________________________________________________________
