# %% [markdown]
# # Send emails to remind student to submit their applications after avg. submit time with ND, and 1 day before deadline approaches

# %% [markdown]
# ## is sending reminder email increase apps submit rate?
# * more students submit their apps after received the email
# * students submit their apps faster than students do not receive the email
#
# * hold off : 5%

# %%
# read data from Laurel
import psycopg2
import pandas as pd
import seaborn as sns
import pymc3 as pm
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
# %matplotlib inline

# %%
conn_laurel = psycopg2.connect("dbname='analytics' user='analytics' host='analytics.cv90snkxh2gd.us-west-2.rds.amazonaws.com' password='!TgP$Ol9Z&6QhKW0tmn9mOW5rYT2J8'")
sql = "select a.*,case when a.group_indicator <= 95 then 1 else 0 end as send_email\
           ,b.submitted_at,case when b.submitted_at is not null then 1 else 0 end as submit_apps\
           ,submitted_at::date-run_date as delta\
       from admissions.email_campaign_reaching_avg_archive a\
       left join applications b on a.application_id = b.id"
df = pd.read_sql(sql,conn_laurel)

# %%
df.groupby(['run_date'])['application_id'].count()
# Out:
# run_date
# 2017-10-27      24
# 2017-10-28    1819
# 2017-10-29    1011
# 2017-10-30     751
# 2017-10-31     205
# 2017-11-01    2309
# 2017-11-02    2019
# 2017-11-03     347
# Name: application_id, dtype: int64

# %%
sns.barplot(x='run_date',y='application_id',hue='submit_apps'
            ,data=df.groupby(['run_date','submit_apps'])['application_id'].count().reset_index())

# %%
df.groupby(['run_date','send_email','submit_apps'])['application_id'].count()
# Out:
# run_date    send_email  submit_apps
# 2017-10-27  0           0                 2
#             1           0                20
#                         1                 2
# 2017-10-28  0           0                67
#                         1                 6
#             1           0              1596
#                         1               150
# 2017-10-29  0           0                37
#                         1                 4
#             1           0               886
#                         1                84
# 2017-10-30  0           0                31
#             1           0               663
#                         1                57
# 2017-10-31  0           0                 9
#             1           0               191
#                         1                 5
# 2017-11-01  0           0                91
#                         1                 3
#             1           0              2123
#                         1                92
# 2017-11-02  0           0                81
#                         1                 1
#             1           0              1864
#                         1                73
# 2017-11-03  0           0                15
#             1           0               329
#                         1                 3
# Name: application_id, dtype: int64

# %% [markdown]
# ### with term, connect and scholarship together

# %%
n1 = df.loc[df['send_email']==0].shape[0]
obs_v1 = df.loc[(df['send_email']==0) & (df['submit_apps']==1)].shape[0]

n2 = df.loc[df['send_email']==1].shape[0]
obs_v2 = df.loc[(df['send_email']==1) & (df['submit_apps']==1)].shape[0]

print("{0} students received reminder emails, {1} of them submit their apps. ({2})".format(n2,obs_v2,obs_v2/n2))
print("{0} students don't received reminder emails, {1} of them submit their apps. ({2})".format(n1,obs_v1,obs_v1/n1))
# Out:
# 8138 students received reminder emails, 466 of them submit their apps. (0.05726222659130007)
# 347 students don't received reminder emails, 14 of them submit their apps. (0.040345821325648415)

# %%
m = (obs_v1+obs_v2)/(n1+n2)
sd = (obs_v1+obs_v2)/(n1+n2)*(1-(obs_v1+obs_v2)/(n1+n2))/(n1+n2)
print("Pool mean: {0}; Pool variance: {1}".format(m,sd))
# Out:
# Pool mean: 0.05657041838538598; Pool variance: 6.289947689933808e-06

# %%
m1 = obs_v1/n1
m2 = obs_v2/n2
sd1 = obs_v1/n1*(1-obs_v1/n1)/n1
sd2 = obs_v2/n2*(1-obs_v2/n2)/n2
print("Students received emails: mean is {0} and variance is {1}".format(m2,sd2))
print("Students don't receive emails: mean is {0} and variance is {1}".format(m1,sd1))
# Out:
# Students received emails: mean is 0.05726222659130007 and variance is 6.63348046167445e-06
# Students don't receive emails: mean is 0.040345821325648415 and variance is 0.0001115793545452659

# %%
# 95% CI:
g1_lower = m1-1.96*np.sqrt(sd1/n1)
g1_upper = m1+1.96*np.sqrt(sd1/n1)
g2_lower = m2-1.96*np.sqrt(sd2/n2)
g2_upper = m2+1.96*np.sqrt(sd2/n2)
print("for student received emails, 95% of CI conversion rate: [{0},{1}]".format(g2_lower,g2_upper))
print("for student don't receive emails, 95% of CI conversion rate: [{0},{1}]".format(g1_lower,g1_upper))
# Out:
# for student received emails, 95% of CI conversion rate: [0.05221413996946318,0.06231031321313696]
# for student don't receive emails, 95% of CI conversion rate: [0.019642120003877626,0.061049522647419203]

# %% [markdown]
# ## let's do a z-test!

# %%
s = m*(1-m)*(1/n1+1/n2)
z = (m2-m1)/np.sqrt(s)
zscore = stats.norm.ppf(.95)
print("z stats is {0}; 90% z score is {1}".format(z,zscore))
# Out:
# z stats is 1.3358457024913746; 90% z score is 1.6448536269514722

# %% [markdown]
# ## let's do a t-test!

# %%
s_t = np.sqrt(((n1-1)*n1*sd1+(n2-1)*n2*sd2)/(n1+n2-2))
t = (m2-m1)/(s_t*np.sqrt(1/n1+1/n2))
tscore = stats.t.ppf(.95,n1+n2-2)
print("t stats is {0}; 90% t score is {1}".format(t,tscore))
# Out:
# t stats is 1.3359655110590007; 90% t score is 1.6450332728996948

# %% [markdown]
# ## do a linear regression - result should be the same

# %%
# ols
ols = smf.ols('submit_apps~C(send_email)',data=df).fit()
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            submit_apps   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.784
# Date:                Fri, 03 Nov 2017   Prob (F-statistic):              0.182
# Time:                        20:54:52   Log-Likelihood:                 393.86
# No. Observations:                8485   AIC:                            -783.7
# Df Residuals:                    8483   BIC:                            -769.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              0.0403      0.012      3.253      0.001       0.016       0.065
# C(send_email)[T.1]     0.0169      0.013      1.336      0.182      -0.008       0.042
# ==============================================================================
# Omnibus:                     6485.328   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            78131.844
# Skew:                           3.838   Prob(JB):                         0.00
# Kurtosis:                      15.731   Cond. No.                         9.79
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = df['send_email']
X = sm.add_constant(X)

sm.OLS(df['submit_apps'],X).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            submit_apps   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.784
# Date:                Fri, 03 Nov 2017   Prob (F-statistic):              0.182
# Time:                        20:50:31   Log-Likelihood:                 393.86
# No. Observations:                8485   AIC:                            -783.7
# Df Residuals:                    8483   BIC:                            -769.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0403      0.012      3.253      0.001       0.016       0.065
# send_email     0.0169      0.013      1.336      0.182      -0.008       0.042
# ==============================================================================
# Omnibus:                     6485.328   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            78131.844
# Skew:                           3.838   Prob(JB):                         0.00
# Kurtosis:                      15.731   Cond. No.                         9.79
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# * add application_type: term/connect/scholarship

# %%
smf.ols('submit_apps~C(send_email)+C(application_type)',data=df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            submit_apps   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     15.90
# Date:                Fri, 03 Nov 2017   Prob (F-statistic):           2.61e-10
# Time:                        20:53:15   Log-Likelihood:                 416.76
# No. Observations:                8485   AIC:                            -825.5
# Df Residuals:                    8481   BIC:                            -797.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             -0.0124      0.065     -0.192      0.848      -0.139       0.114
# C(send_email)[T.1]                     0.0162      0.013      1.278      0.201      -0.009       0.041
# C(application_type)[T.scholarship]     0.0617      0.064      0.964      0.335      -0.064       0.187
# C(application_type)[T.term]            0.0188      0.064      0.292      0.770      -0.107       0.145
# ==============================================================================
# Omnibus:                     6439.472   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            76401.302
# Skew:                           3.805   Prob(JB):                         0.00
# Kurtosis:                      15.577   Cond. No.                         72.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## let's do a bayesian ab testing!

# %% [markdown]
# ### use beta distribution for priors and bernoulli distribution for likelihood

# %% [markdown]
# ### P(RateOfSucess|Success) = Beta(a,b)
#
# * a: number of times success observed
# * b: number of times failure observed
# * This distribution tells us which rates of success are most likely given the data we have.
#
# * In Bayesian terms, estimates of the true rate of success given observed data is referred to as the Likelihood.
#
# ### Posterior = Likelihood\*Prior

# %% [markdown]
# ### how to decide prior?
# * if your data are arrays, plot to find distribution (e.g. grades of students in diff classes)
# * in our case, we have 2 conversion rate to compare, try Beta
#
# ### is prior_v1 = prior_v2 all time?
# * No. depends on your preference on your priors. how strong belief you have in your data.
# * in our case, our hold-off group is 5%, means we have a strong bias sending emails will improve conversion rate.

# %% [markdown]
# to simply question, we set the priors the same in two groups: Beta(1.4,34). reason to pick a = 1.4 and b = 34 is due to mean and variance of p above. (mean is somewhere 0.05)

# %%
with pm.Model() as model: # context management
    # define priors
    prior_v1 = pm.Beta('prior_v1', alpha=1.4, beta=34)
    prior_v2 = pm.Beta('prior_v2', alpha=1.4, beta=34)
    #prior_v1 = pm.Normal('prior_v1', mu=m1, sd=sd1)
    #prior_v2 = pm.Normal('prior_v2', mu=m2, sd=sd2)

    # define likelihood
    like_v1 = pm.Binomial('like_v1', n=n1, p=prior_v1, observed=obs_v1)
    like_v2 = pm.Binomial('like_v2', n=n2, p=prior_v2, observed=obs_v2)
    
    ## define metrics
    pm.Deterministic('difference', prior_v2 - prior_v1)
    pm.Deterministic('relation', (prior_v2/prior_v1) - 1)
    
    # inference
    trace = pm.sample(draws=50000, step=pm.Metropolis(), start=pm.find_MAP(), progressbar=True)
# Out:
# logp = -1.7538, ||grad|| = 0.00017864: 100%|██████████| 13/13 [00:00<00:00, 1572.71it/s]
# 100%|██████████| 50500/50500 [00:10<00:00, 4723.41it/s]

# %%
_ = pm.traceplot(trace[1000:], grid=True)

# %%
_ = pm.plot_posterior(trace[1000:], varnames=['difference', 'relation'], 
                      ref_val=0, color='#87ceeb')

# %% [markdown]
# ### baysian in ols
# * set likelihood to be Bernoulli. in order to make sure the model output is between 0 and 1, prior of intercept and x_coef are set uniform within a very small range.

# %%
with pm.Model() as model_b:
    #priors
    intercept = pm.Uniform('Intercept',lower=0,upper=0.1)
    x_coef = pm.Uniform('x',lower=0.0001,upper=0.1)
    #sigma = pm.HalfCauchy('sigma',beta=10,testval=1.0)
    
    #likelihood
    likelihood = pm.Bernoulli('y',p=intercept+x_coef*df['send_email'],observed=df['submit_apps'])
    
    trace = pm.sample(10000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 10500/10500 [00:30<00:00, 347.42it/s]

# %%
pm.plot_posterior(trace,alpha_level=0.1)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x115385978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1153e7fd0>], dtype=object)

# %% [markdown]
# ### baysian in ols 2
# * instead of uniform distribution. since we know that the conversion rate is around 5%, let's just set intercept to be a very strict uniform distribution of U(0.04,0.06).

# %%
with pm.Model() as model_b:
    #priors
    #intercept = pm.Normal('Intercept',mu=0.05,sd=1e-10)
    intercept = pm.Uniform('Intercept',lower=0.04,upper=0.06)
    x_coef = pm.Uniform('x',lower=-0.04,upper=0.9)
    #sigma = pm.HalfCauchy('sigma',beta=10,testval=1.0)
    
    #likelihood
    likelihood = pm.Bernoulli('y',p=intercept+x_coef*df['send_email'],observed=df['submit_apps'])
    
    trace = pm.sample(10000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|█████████▉| 10496/10500 [00:26<00:00, 393.93it/s]/anaconda/lib/python3.6/site-packages/pymc3/step_methods/hmc/nuts.py:451: UserWarning: The acceptance probability in chain 0 does not match the target. It is 0.902293734881, but should be close to 0.8. Try to increase the number of tuning steps.
#   % (self._chain_id, mean_accept, target_accept))
# 100%|██████████| 10500/10500 [00:26<00:00, 393.89it/s]

# %%
_ = pm.traceplot(trace[1000:], grid=True)

# %%
pm.plot_posterior(trace,alpha_level=0.1)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1199a0ba8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1182dd470>], dtype=object)

# %% [markdown]
# ### bayesian: logistics regression

# %%
with pm.Model() as model_glm:
    #family = pm.glm.families.StudentT()
    pm.glm.GLM.from_formula('submit_apps~send_email',df,family=pm.glm.families.Binomial())
    trace=pm.sample(10000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 10500/10500 [01:34<00:00, 111.65it/s]

# %%
_ = pm.traceplot(trace[1000:], grid=True)

# %%
pm.plot_posterior(trace,alpha_level=0.1)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1154abc18>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x115c37470>], dtype=object)

# %% [markdown]
# ### bayesian: logistics regression with application_type

# %%
with pm.Model() as model_glm_2:
    #family = pm.glm.families.StudentT()
    pm.glm.GLM.from_formula('submit_apps~send_email+C(application_type)',df,family=pm.glm.families.Binomial())
    trace=pm.sample(10000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████| 10500/10500 [03:07<00:00, 55.86it/s]/anaconda/lib/python3.6/site-packages/pymc3/step_methods/hmc/nuts.py:451: UserWarning: The acceptance probability in chain 0 does not match the target. It is 0.155232726983, but should be close to 0.8. Try to increase the number of tuning steps.
#   % (self._chain_id, mean_accept, target_accept))
# /anaconda/lib/python3.6/site-packages/pymc3/step_methods/hmc/nuts.py:467: UserWarning: Chain 0 contains 2931 diverging samples after tuning. If increasing `target_accept` does not help try to reparameterize.
#   % (self._chain_id, n_diverging))

# %%
_ = pm.traceplot(trace[1000:], grid=True)

# %%
pm.plot_posterior(trace,alpha_level=0.1)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x118111080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x118754cc0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x118766b38>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x117f9d9e8>], dtype=object)

# %%
# draw a Beta distribution
from scipy.stats import beta
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(1, 1)

for i in range(8,12):
    a = 1.4
    b = i
    mean, var, skew, kurt = beta.stats(a, b, moments='mvsk')
    
    print (a,b)
    x = np.linspace(beta.ppf(0.01, a, b),beta.ppf(0.99, a, b), 100)
    ax.plot(x, beta.pdf(x, a, b),'r-', lw=5, alpha=0.6, label='beta pdf')

# %%
# 
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.mlab as mlab
import math

mu = m
variance = sd
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x,mlab.normpdf(x, mu, sigma))
plt.show()
